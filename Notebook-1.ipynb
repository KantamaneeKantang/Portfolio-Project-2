-- %%
SELECT country, year, energy_per_capita, electricity_generation
FROM Energy
WHERE energy_per_capita is not null
-- Out:
-- (10241 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.141
-- ...
